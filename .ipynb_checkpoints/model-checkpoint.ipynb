# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import QuantileTransformer
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
import joblib

# %%
data = pd.read_csv('train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           576 non-null    int64
#  1   nums/length username  576 non-null    float64
#  2   fullname words        576 non-null    int64
#  3   nums/length fullname  576 non-null    float64
#  4   name==username        576 non-null    int64
#  5   description length    576 non-null    int64
#  6   external URL          576 non-null    int64
#  7   private               576 non-null    int64
#  8   #posts                576 non-null    int64
#  9   #followers            576 non-null    int64
#  10  #follows              576 non-null    int64
#  11  fake                  576 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 54.1 KB

# %%
data.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.27               0                   0.0
# 1            1                  0.00               2                   0.0
# 2            1                  0.10               2                   0.0
# 3            1                  0.00               1                   0.0
# 4            1                  0.00               2                   0.0
#
#    name==username  description length  external URL  private  #posts  \
# 0               0                  53             0        0      32
# 1               0                  44             0        0     286
# 2               0                   0             0        1      13
# 3               0                  82             0        0     679
# 4               0                   0             0        1       6
#
#    #followers  #follows  fake
# 0        1000       955     0
# 1        2740       533     0
# 2         159        98     0
# 3         414       651     0
# 4         151       126     0

# %%
features = ['profile pic', 'fullname words', 'name==username', 'private', '#posts', '#followers', '#follows']
label = ['fake']

# %%
scaler = QuantileTransformer(n_quantiles=100)
data[features] = scaler.fit_transform(data[features])
data.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0          1.0                  0.27        0.000000                   0.0
# 1          1.0                  0.00        0.752525                   0.0
# 2          1.0                  0.10        0.752525                   0.0
# 3          1.0                  0.00        0.343434                   0.0
# 4          1.0                  0.00        0.752525                   0.0
#
#    name==username  description length  external URL  private    #posts  \
# 0             0.0                  53             0      0.0  0.636364
# 1             0.0                  44             0      0.0  0.909603
# 2             0.0                   0             0      1.0  0.545455
# 3             0.0                  82             0      0.0  0.970431
# 4             0.0                   0             0      1.0  0.439394
#
#    #followers  #follows  fake
# 0    0.812467  0.867336     0
# 1    0.903221  0.724404     0
# 2    0.506473  0.345324     0
# 3    0.666150  0.782242     0
# 4    0.500550  0.385129     0

# %%
X = data[features]
Y = data[label]

# %%
model = RandomForestClassifier(n_estimators=300)
model.fit(X, Y.values.ravel())
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
test_data = pd.read_csv('test.csv')
test_data[features] = scaler.fit_transform(test_data[features])
X_test = test_data[features]
Y_test = test_data[label]
test_data.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0          1.0                  0.33        0.323232                  0.33
# 1          1.0                  0.00        0.979798                  0.00
# 2          1.0                  0.00        0.762626                  0.00
# 3          1.0                  0.00        0.323232                  0.00
# 4          1.0                  0.50        0.323232                  0.00
#
#    name==username  description length  external URL  private    #posts  \
# 0             1.0                  30             0      1.0  0.702822
# 1             0.0                  64             0      1.0  0.373737
# 2             0.0                  82             0      1.0  0.941308
# 3             0.0                 143             0      1.0  0.923053
# 4             0.0                  76             0      1.0  0.464646
#
#    #followers  #follows  fake
# 0    0.710438  0.707019     0
# 1    0.136105  0.036980     0
# 2    0.605356  0.750024     0
# 3    0.954372  0.997396     0
# 4    0.521008  0.504468     0

# %%
Y_pred = model.predict(X_test)

# %%
print(accuracy_score(Y_test,Y_pred)*100)
# Out:
# 90.83333333333333

# %%
plot_confusion_matrix(model, X=X_test, y_true=Y_test)
